# %% [markdown]
# ##### Copyright 2019 The TensorFlow Authors.

# %%
#@title Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
# https://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.

# %%
# !git clone -b feature/modulo-estimacion-costos-flexo https://github.com/madmkt04-dot/blank-app.git
# %cd blank-app
# !ls
# Out:
# Cloning into 'blank-app'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 39 (delta 9), reused 9 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (39/39), 24.42 KiB | 8.14 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/blank-app
# ai_copilot.py  pricing_engine.py  requirements.txt  streamlit_app.py
# LICENSE        README.md	  site

# %%
# !streamlit run streamlit_app.py --server.port 8501 --server.address 0.0.0.0 > /content/streamlit.log 2>&1 &

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 62.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 97.4 MB/s eta 0:00:00
# ...

# %%
from pricing_engine import FlexoEstimateInput, estimate_flexo_cost

data = FlexoEstimateInput(
    product="Etiqueta adhesiva flexográfica",
    customer="Cliente demo",
    quantity_units=100000,
    advance_m=0.10,
    lanes=2,
    web_width_m=0.33,
    substrate_cost_per_m2=1.80,
    ink_consumption_g_m2=3.50,
    ink_cost_per_kg=85.0,
    varnish_consumption_g_m2=1.20,
    varnish_cost_per_kg=45.0,
    startup_waste_m=250.0,
    run_waste_pct=3.0,
    machine_speed_ml_h=3600.0,
    setup_hours=1.20,
    machine_rate_h=220.0,
    labor_rate_h=35.0,
    labor_hours_extra=0.50,
    plate_cost=450.0,
    prepress_cost=120.0,
    die_cut_cost=180.0,
    rewind_cost=100.0,
    packing_cost=80.0,
    overhead_pct=12.0,
    admin_sales_pct=7.0,
    commission_pct=3.0,
    freight_cost=150.0,
    finance_pct=1.5,
    markup_on_cost_pct=30.0,
    margin_on_sales_pct=25.0,
    minimum_contribution_pct=15.0,
    strategic_value_premium_pct=8.0,
    market_price=0.0,
    tax_pct=18.0
)

result = estimate_flexo_cost(data)
result
# Out:
# {'quantity_units': 100000,
#  'net_linear_m': 5000.0,
#  'startup_waste_m': 250.0,
#  'run_waste_m': 150.0,
#  'total_linear_m': 5400.0,
#  'area_m2': 1782.0,
#  'run_hours': 1.5,
#  'setup_hours': 1.2,
#  'total_machine_hours': 2.7,
#  'substrate_cost': 3207.6,
#  'ink_cost': 530.145,
#  'varnish_cost': 96.228,
#  'direct_material_cost': 3833.973,
#  'setup_machine_cost': 264.0,
#  'run_machine_cost': 330.0,
#  'machine_cost': 594.0,
#  'direct_labor_cost': 112.0,
#  'plate_cost': 450.0,
#  'prepress_cost': 120.0,
#  'finishing_cost': 360.0,
#  'overhead_cost': 656.39676,
#  'manufacturing_cost': 6126.36976,
#  'admin_sales_cost': 428.8458832,
#  'commission_cost': 183.79109279999997,
#  'freight_cost': 150.0,
#  'finance_cost': 91.89554639999999,
#  'commercial_cost': 854.5325224,
#  'total_cost': 6980.902282399999,
#  'variable_cost': 4366.473,
#  'fixed_order_cost': 834.0,
#  'price_markup_cost': 9075.17296712,
#  'price_margin_sales': 9307.869709866665,
# ...

# %%
# !npm install -g localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋
# added 22 packages in 2s
# ⠋
# ⠋3 packages are looking for funding
# ⠋  run `npm fund` for details
# ⠋

# %%
# !streamlit run streamlit_app.py --server.port 8501 --server.address 0.0.0.0 > /content/streamlit.log 2>&1 &

# %%
# !streamlit run streamlit_app.py --server.port 8501 --server.address 0.0.0.0 > /content/streamlit.log 2>&1 &

# %%
# !npx localtunnel --port 8501
# Out:
# ⠙⠹⠸⠼⠴your url is: https://true-baboons-vanish.loca.lt
# ⠙
